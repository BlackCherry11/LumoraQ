# %%
# !pip install pennylane
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[2], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
import pennylane as qml

print(qml.__version__)
# Out:
# 0.45.0

# %%
import pennylane as qml
from pennylane import numpy as np

dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev)
def circuit(x):

    qml.RX(x[0], wires=0)
    qml.RY(x[1], wires=1)

    return [
        qml.expval(qml.PauliZ(0)),
        qml.expval(qml.PauliZ(1))
    ]

print(circuit([0.5, 0.2]))
# Out:
# [np.float64(0.8775825618903726), np.float64(0.9800665778412415)]

# %%
print(qml.draw(circuit)([0.5, 0.2]))
# Out:
# 0: ──RX(0.50)─┤  <Z>
# 1: ──RY(0.20)─┤  <Z>

# %%
import pennylane as qml
from pennylane import numpy as np

dev = qml.device("default.qubit", wires=2)

@qml.qnode(dev)
def vqc(x, weights):

    qml.RX(x[0], wires=0)
    qml.RY(x[1], wires=1)

    qml.RY(weights[0], wires=0)
    qml.RY(weights[1], wires=1)

    qml.CNOT(wires=[0,1])

    return qml.expval(qml.PauliZ(0))

# %%
weights
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 weights
#
# NameError: name 'weights' is not defined

# %%
Conv2d(...)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 Conv2d(...)
#
# NameError: name 'Conv2d' is not defined

# %%
weights = np.array([0.1, 0.2])

print(
    vqc(
        [0.5, 0.2],
        weights
    )
)
# Out:
# 0.8731983044562818

# %%
weights = np.array([1.5, 2.0])

# %%
print(vqc([0.5, 0.2], weights))
# Out:
# 0.06207773466049871

# %%
X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

Y = np.array([
    -1,
     1,
     1,
    -1
])

# %%
def loss(weights):

    total = 0

    for x, y in zip(X, Y):

        prediction = vqc(x, weights)

        total += (prediction - y)**2

    return total / len(X)

# %%
weights = np.array([0.1, 0.2])

print(loss(weights))
# Out:
# 1.6395251613752957

# %%
loss = criterion(outputs, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 loss = criterion(outputs, labels)
#
# NameError: name 'criterion' is not defined

# %%
weights = np.array([1.5, 2.0])

print(loss(weights))
# Out:
# 1.0032322399146505

# %%
opt = qml.GradientDescentOptimizer(stepsize=0.1)

weights = np.array(
    [0.1, 0.2],
    requires_grad=True
)

# %%
for step in range(50):

    weights = opt.step(loss, weights)

    if (step + 1) % 10 == 0:
        print(
            f"Step {step+1}: Loss = {loss(weights):.4f}"
        )
# Out:
# Step 10: Loss = 1.5790
# Step 20: Loss = 1.2650
# Step 30: Loss = 1.0290
# Step 40: Loss = 1.0019
# Step 50: Loss = 1.0001

# %%
loss.backward()
optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 loss.backward()
#       2 optimizer.step()
#
# AttributeError: 'function' object has no attribute 'backward'

# %%
print("Final weights:", weights)
print("Final loss:", loss(weights))
# Out:
# Final weights: [1.55712445 0.2       ]
# Final loss: 1.0001207361321398

# %%
for x, y in zip(X, Y):

    prediction = vqc(x, weights)

    print(
        f"Input={x}, Prediction={prediction:.4f}, True={y}"
    )
# Out:
# Input=[0 0], Prediction=0.0137, True=-1
# Input=[0 1], Prediction=0.0137, True=1
# Input=[1 0], Prediction=0.0074, True=1
# Input=[1 1], Prediction=0.0074, True=-1

# %%
print("Final weights:", weights)
print("Final loss:", loss(weights))
# Out:
# Final weights: [1.55712445 0.2       ]
# Final loss: 1.0001207361321398

# %%
@qml.qnode(dev)
def vqc(x, weights):

    qml.RX(x[0], wires=0)
    qml.RY(x[1], wires=1)

    qml.RY(weights[0], wires=0)
    qml.RZ(weights[1], wires=0)

    qml.RY(weights[2], wires=1)
    qml.RZ(weights[3], wires=1)

    qml.CNOT(wires=[0,1])

    return qml.expval(qml.PauliZ(0))

# %%
weights = np.array(
    [0.1, 0.2, 0.3, 0.4],
    requires_grad=True
)

# %%
loss(weights)
# Out:
# tensor(1.63952516, requires_grad=True)

# %%
loss = criterion(outputs, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 loss = criterion(outputs, labels)
#
# NameError: name 'criterion' is not defined

# %%
opt = qml.GradientDescentOptimizer(stepsize=0.1)

for step in range(100):

    weights = opt.step(loss, weights)

    if (step + 1) % 20 == 0:
        print(
            f"Step {step+1}: Loss = {loss(weights):.4f}"
        )
# Out:
# Step 20: Loss = 1.2650
# Step 40: Loss = 1.0019
# Step 60: Loss = 1.0000
# Step 80: Loss = 1.0000
# Step 100: Loss = 1.0000

# %%
print("Final weights:", weights)
print("Final loss:", loss(weights))
# Out:
# Final weights: [1.57078278 0.2        0.3        0.4       ]
# Final loss: 1.0000000001186147

# %%
for x, y in zip(X, Y):

    prediction = vqc(x, weights)

    print(
        f"Input={x}, Prediction={prediction:.4f}, True={y}"
    )
# Out:
# Input=[0 0], Prediction=0.0000, True=-1
# Input=[0 1], Prediction=0.0000, True=1
# Input=[1 0], Prediction=0.0000, True=1
# Input=[1 1], Prediction=0.0000, True=-1

# %%
print(weights)
# Out:
# [1.57078278 0.2        0.3        0.4       ]

# %%
print(loss(weights))
# Out:
# 1.0000000001186147

# %%
print(vqc([0,0], weights))
print(vqc([0,1], weights))
print(vqc([1,0], weights))
print(vqc([1,1], weights))
# Out:
# 1.3550819441709994e-05
# 1.3550819441876527e-05
# 7.321538990801013e-06
# 7.32153899063448e-06

# %%
model = StrongCNN()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 model = StrongCNN()
#
# NameError: name 'StrongCNN' is not defined

# %%
import torch
import torch.nn as nn

class StrongCNN(nn.Module):

    def __init__(self):
        super().__init__()

        self.features = nn.Sequential(

            nn.Conv2d(3, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.Conv2d(32, 32, 3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),

            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.Conv2d(64, 64, 3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),

            nn.MaxPool2d(2)
        )

        self.classifier = nn.Sequential(

            nn.Flatten(),

            nn.Linear(64 * 16 * 16, 256),

            nn.ReLU(),

            nn.Dropout(0.4),

            nn.Linear(256, 10)
        )

    def forward(self, x):

        x = self.features(x)
        x = self.classifier(x)

        return x

# %%
model = StrongCNN()

print(model)
# Out:
# StrongCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (12): ReLU()
# ...

# %%
device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

model = model.to(device)

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(
    model.parameters(),
    lr=0.0005
)

# %%
train_loader
test_loader
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 train_loader
#       2 test_loader
#
# NameError: name 'train_loader' is not defined

# %%
print(train_loader)
print(test_loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 print(train_loader)
#       2 print(test_loader)
#
# NameError: name 'train_loader' is not defined

# %%
model = StrongCNN()
model.load_state_dict(torch.load("cnn.pth"))
model.eval()
# Out:
# StrongCNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (5): ReLU()
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (9): ReLU()
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, bias=True, track_running_stats=True)
#     (12): ReLU()
# ...

# %%
print(train_loader)
print(test_loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 print(train_loader)
#       2 print(test_loader)
#
# NameError: name 'train_loader' is not defined
